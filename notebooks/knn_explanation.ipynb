# %%
# Load the Kedro IPython extension
# %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
import pandas as pd
import plotly.graph_objects as go
from dash import Dash, dcc, html
from dash.dependencies import Input, Output
from plotly.subplots import make_subplots

# %%
explanation = catalog.load("explanation")
closest_customers_detail = catalog.load("closest_customers_detail")
# Out:
# [06/18/25 20:16:50] INFO     Loading data from explanation (CSVDataset)...                      ]8;id=651691;file:///Users/Carlos_Davalos/Projects/B2B_COPEC/b2b-pricing-model/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=470692;file:///Users/Carlos_Davalos/Projects/B2B_COPEC/b2b-pricing-model/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#403\403]8;;\
#                     INFO     Loading data from closest_customers_detail (CSVDataset)...         ]8;id=47800;file:///Users/Carlos_Davalos/Projects/B2B_COPEC/b2b-pricing-model/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=721309;file:///Users/Carlos_Davalos/Projects/B2B_COPEC/b2b-pricing-model/.venv/lib/python3.11/site-packages/kedro/io/data_catalog.py#403\403]8;;\

# %%
explanation[explanation["customer_id"] == "idg_002268"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                              feature  customer_value  avg_neighbor_value  \
# 140296      share_customer_region_11    0.000000e+00        0.000000e+00
# 140297      share_customer_region_12    0.000000e+00        0.000000e+00
# 140298      share_customer_region_10    1.512356e-02        9.546970e-02
# 140299      share_customer_region_15    0.000000e+00        8.350773e-03
# 140300      share_customer_region_14    1.670819e-02        1.538779e-03
# 140301       share_customer_region_1    4.650290e-05        6.819595e-02
# 140302       share_customer_region_9    1.534732e-01        2.279596e-02
# 140303       share_customer_region_3    1.093897e-03        5.684753e-02
# 140304       share_customer_region_4    9.397470e-04        8.925770e-03
# 140305      share_customer_region_13    5.736959e-03        3.672276e-02
# 140306       share_customer_region_6    5.283058e-02        2.665874e-02
# 140307       share_customer_region_8    2.137783e-01        3.345284e-01
# 140308      share_customer_region_16    1.535724e-01        4.487072e-02
# 140309       share_customer_region_5    5.179012e-04        1.114678e-01
# 140310       share_customer_region_2    3.119511e-01        2.857327e-02
# 140311       share_customer_region_7    1.301922e-01        3.007638e-01
# 140312      c_tct_yearly_perc_volume    9.470015e-01        8.796975e-01
# 140313  c_weighted_competitive_index    7.012209e+00        1.171460e+01
# 140314      c_yearly_network_volumen    6.177348e+06        5.984049e+06
#
#         scaled_customer_value  scaled_avg_neighbor_value  scaled_distance  \
# 140296              -0.011425                  -0.011425         0.000000
# 140297              -0.011721                  -0.011721         0.000000
# 140298              -0.011922                  -0.011835         0.000097
# 140299              -0.017670                  -0.017372         0.000298
# 140300              -0.015482                  -0.015968         0.000486
# 140301              -0.017118                  -0.015977         0.001142
# 140302              -0.012710                  -0.013986         0.001276
# 140303              -0.015970                  -0.014545         0.001425
# 140304              -0.066144                  -0.063315         0.002830
# 140305              -0.061275                  -0.057745         0.003621
# 140306              -0.038586                  -0.042995         0.004409
# 140307              -0.018727                  -0.016459         0.004878
# 140308              -0.009640                  -0.019400         0.009760
# 140309              -0.046566                  -0.036699         0.009867
# 140310              -0.015374                  -0.027757         0.012383
# 140311              -0.028936                   0.009374         0.074365
# 140312               0.073452                  -0.243255         0.316707
# 140313              -0.805912                  -0.369626         0.436286
# 140314              10.453332                  10.118878         1.469004
#
#         value_difference customer_id
# 140296          0.000000  idg_002268
# 140297          0.000000  idg_002268
# 140298          0.080346  idg_002268
# 140299          0.008351  idg_002268
# 140300          0.015169  idg_002268
# 140301          0.068149  idg_002268
# 140302          0.130677  idg_002268
# 140303          0.055754  idg_002268
# 140304          0.007986  idg_002268
# 140305          0.030986  idg_002268
# 140306          0.026172  idg_002268
# 140307          0.120750  idg_002268
# 140308          0.108702  idg_002268
# 140309          0.110950  idg_002268
# 140310          0.283378  idg_002268
# 140311          0.170572  idg_002268
# 140312          0.067304  idg_002268
# 140313          4.702392  idg_002268
# 140314     193299.030000  idg_002268

# %%
# Define your percentage features
perc_features = [
    "share_customer_region_14",
    "share_customer_region_11",
    "share_customer_region_5",
    "share_customer_region_9",
    "share_customer_region_4",
    "share_customer_region_8",
    "share_customer_region_12",
    "share_customer_region_15",
    "share_customer_region_16",
    "share_customer_region_6",
    "share_customer_region_7",
    "share_customer_region_10",
    "share_customer_region_1",
    "share_customer_region_3",
    "share_customer_region_13",
    "share_customer_region_2",
]

feature_dict = {
    "fleet_size": "Fleet Size",
    "c_yearly_volumen": "TCT Annual Volume",
    "c_yearly_network_volumen": "Network Annual Volume",
    "c_yearly_avg_volume_per_trx": "TCT Avg Volume per Transaction (Annual)",
    "region_diversity_index": "Regional Diversity Index",
    "c_weighted_competitive_index": "Weighted Competitiveness Index",
    "c_tct_yearly_perc_volume": "TCT Share of Annual Volume (%)",
    "share_customer_region_13": "Share of Region 13",
    "share_customer_region_7": "Share of Region 7",
    "share_customer_region_3": "Share of Region 3",
    "share_customer_region_6": "Share of Region 6",
    "share_customer_region_16": "Share of Region 16",
    "share_customer_region_10": "Share of Region 10",
    "share_customer_region_15": "Share of Region 15",
    "share_customer_region_14": "Share of Region 14",
    "share_customer_region_8": "Share of Region 8",
    "share_customer_region_4": "Share of Region 4",
    "share_customer_region_9": "Share of Region 9",
    "share_customer_region_2": "Share of Region 2",
    "share_customer_region_5": "Share of Region 5",
    "share_customer_region_1": "Share of Region 1",
    "share_customer_region_11": "Share of Region 11",
    "share_customer_region_12": "Share of Region 12",
}

# %%
explanation
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                              feature  customer_value  avg_neighbor_value  \
# 0           c_tct_yearly_perc_volume    1.000000e+00        1.000000e+00
# 1            share_customer_region_1    0.000000e+00        0.000000e+00
# 2            share_customer_region_5    0.000000e+00        0.000000e+00
# 3            share_customer_region_4    0.000000e+00        0.000000e+00
# 4           share_customer_region_12    0.000000e+00        0.000000e+00
# ...                              ...             ...                 ...
# 145839       share_customer_region_7    1.824802e-01        1.464491e-02
# 145840       share_customer_region_5    8.222431e-03        9.227299e-01
# 145841  c_weighted_competitive_index    7.669360e+00        6.767271e+00
# 145842      c_tct_yearly_perc_volume    2.487963e-01        2.590016e-01
# 145843      c_yearly_network_volumen    1.379242e+06        1.240153e+06
#
#         scaled_customer_value  scaled_avg_neighbor_value  scaled_distance  \
# 0                    0.322843                   0.322843         0.000000
# 1                   -0.017119                  -0.017119         0.000000
# 2                   -0.046612                  -0.046612         0.000000
# 3                   -0.066477                  -0.066477         0.000000
# 4                   -0.011721                  -0.011721         0.000000
# ...                       ...                        ...              ...
# 145839              -0.017192                  -0.054888         0.037696
# 145840              -0.045881                   0.035444         0.082011
# 145841              -0.744942                  -0.828637         0.109826
# 145842              -3.212031                  -3.164009         0.202582
# 145843               2.151456                   1.910798         0.295527
#
#         value_difference  customer_id
# 0               0.000000  id_10002106
# 1               0.000000  id_10002106
# 2               0.000000  id_10002106
# 3               0.000000  id_10002106
# 4               0.000000  id_10002106
# ...                  ...          ...
# 145839          0.167835   idg_006299
# 145840          0.914507   idg_006299
# 145841          0.902089   idg_006299
# 145842          0.010205   idg_006299
# 145843     139089.117500   idg_006299
#
# [145844 rows x 8 columns]

# %%
explanation["pretty_feature"] = explanation["feature"].map(feature_dict)

# %%
from dash import Input, Output, dash_table

# Load your data
explanation = explanation
neighbors_df = closest_customers_detail

# Define percentage share features
perc_features = [
    "share_customer_region_14",
    "share_customer_region_11",
    "share_customer_region_5",
    "share_customer_region_9",
    "share_customer_region_4",
    "share_customer_region_8",
    "share_customer_region_12",
    "share_customer_region_15",
    "share_customer_region_16",
    "share_customer_region_6",
    "share_customer_region_7",
    "share_customer_region_10",
    "share_customer_region_1",
    "share_customer_region_3",
    "share_customer_region_13",
    "share_customer_region_2",
]

# App
app = Dash(__name__)

# Initial column options for the column selector
all_columns = [
    {"label": col, "value": col}
    for col in neighbors_df.columns
    if col != "source_customer_id"
]

app.layout = html.Div(
    [
        html.H2("Desglose de Variables por Cliente"),
        dcc.Dropdown(
            id="customer-selector",
            options=[
                {"label": cid, "value": cid}
                for cid in explanation["customer_id"].unique()
            ],
            value=explanation["customer_id"].unique()[0],
            style={"width": "400px", "margin-bottom": "20px"},
        ),
        dcc.Graph(id="polar-subplots"),
        html.H3("Detalle de Vecinos Más Cercanos"),
        html.Div(
            [
                html.Label("Select columns to show:"),
                dcc.Dropdown(
                    id="column-selector",
                    options=all_columns,
                    value=[
                        all_columns[0]["value"]
                    ],  # Start with the first column selected
                    multi=True,
                    style={"width": "100%", "margin-bottom": "10px"},
                ),
            ]
        ),
        dash_table.DataTable(
            id="neighbors-table",
            columns=[],
            data=[],
            page_size=10,
            style_table={"overflowX": "auto"},
            style_cell={
                "textAlign": "left",
                "minWidth": "120px",
                "maxWidth": "300px",
                "whiteSpace": "normal",
            },
            style_header={"backgroundColor": "lightgrey", "fontWeight": "bold"},
        ),
    ]
)


@app.callback(Output("polar-subplots", "figure"), Input("customer-selector", "value"))
def update_chart(customer_id):
    test = explanation[explanation["customer_id"] == customer_id]

    perc_features_df = test[test["feature"].isin(perc_features)]
    non_perc_features_df = test[~test["feature"].isin(perc_features)]

    fig = make_subplots(
        rows=1,
        cols=2,
        specs=[[{"type": "polar"}, {"type": "polar"}]],
    )

    fig.add_trace(
        go.Scatterpolar(
            r=perc_features_df["customer_value"],
            theta=perc_features_df["pretty_feature"],
            fill="toself",
            line=dict(color="red", width=3),
            name="Cliente",
        ),
        row=1,
        col=1,
    )

    fig.add_trace(
        go.Scatterpolar(
            r=perc_features_df["avg_neighbor_value"],
            theta=perc_features_df["pretty_feature"],
            fill="toself",
            line=dict(color="blue", width=3),
            opacity=0.6,
            name="Promedio Vecinos (Top 5)",
        ),
        row=1,
        col=1,
    )

    fig.add_trace(
        go.Scatterpolar(
            r=non_perc_features_df["scaled_customer_value"],
            theta=non_perc_features_df["pretty_feature"],
            fill="toself",
            line=dict(color="red", width=3),
            showlegend=False,
        ),
        row=1,
        col=2,
    )

    fig.add_trace(
        go.Scatterpolar(
            r=non_perc_features_df["scaled_avg_neighbor_value"],
            theta=non_perc_features_df["pretty_feature"],
            fill="toself",
            line=dict(color="blue", width=3),
            opacity=0.6,
            showlegend=False,
        ),
        row=1,
        col=2,
    )

    fig.update_layout(
        height=550,
        showlegend=True,
        margin=dict(t=100),
    )

    return fig


@app.callback(
    Output("neighbors-table", "columns"),
    Output("neighbors-table", "data"),
    Input("customer-selector", "value"),
    Input("column-selector", "value"),
)
def update_neighbors_table(customer_id, selected_columns):
    if not selected_columns:
        return [], []

    # Ensure 'source_customer_id' is always shown
    fixed_column = "source_customer_id"
    columns_to_show = [fixed_column] + [
        col for col in selected_columns if col != fixed_column
    ]

    # Filter neighbors for the selected customer_id
    filtered = neighbors_df[neighbors_df[fixed_column] == customer_id]
    print(filtered)

    # Format the data for display
    formatted_data = []
    for _, row in filtered.iterrows():
        formatted_row = {}
        for col in columns_to_show:
            value = row.get(col, "")
            if pd.isna(value):
                formatted_row[col] = ""
            elif col in perc_features:
                formatted_row[col] = (
                    f"{value:.2%}" if isinstance(value, (float, int)) else value
                )
            elif isinstance(value, (float, int)):
                formatted_row[col] = f"{value:.2f}"
            else:
                formatted_row[col] = value
        formatted_data.append(formatted_row)

    # Define columns for dash table
    columns = [{"name": "Customer ID", "id": fixed_column}] + [
        {"name": col, "id": col} for col in selected_columns if col != fixed_column
    ]

    return columns, formatted_data


if __name__ == "__main__":
    app.run(debug=True, port=8080)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.lib.display.IFrame object at 0x313e58050>
#    customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 0  id_10588990                  21037.98                      5.853351
# 1  id_12739765                  45413.30                      7.492767
# 2  id_12999049                  39822.42                      7.151045
# 3  id_13359459                  94769.73                      5.812761
# 4  id_14037504                   7157.68                      6.464347
# 5  id_10002106                  54587.16                      6.537076
#
#    share_customer_region_13  share_customer_region_7  share_customer_region_3  \
# 0                  0.000000                 0.080379                 0.000000
# 1                  0.000000                 0.000000                 0.000000
# 2                  0.000000                 0.000728                 0.000000
# 3                  0.000000                 0.000000                 0.000000
# 4                  0.000000                 0.010397                 0.000000
# 5                  0.082142                 0.000000                 0.105354
#
#    share_customer_region_6  share_customer_region_16  \
# 0                 0.000000                       0.0
# 1                 0.000000                       0.0
# 2                 0.001544                       0.0
# 3                 0.000000                       0.0
# 4                 0.000000                       0.0
# 5                 0.000000                       0.0
#
#    share_customer_region_10  share_customer_region_15  ...  \
# 0                  0.000000                       0.0  ...
# 1                  0.000000                       0.0  ...
# 2                  0.984124                       0.0  ...
# 3                  0.000000                       0.0  ...
# 4                  0.973099                       0.0  ...
# 5                  0.000000                       0.0  ...
#
#    share_customer_region_5  share_customer_region_1  share_customer_region_11  \
# 0                      0.0                      0.0                  0.919621
# 1                      0.0                      0.0                  0.000000
# 2                      0.0                      0.0                  0.000000
# 3                      0.0                      0.0                  0.000000
# 4                      0.0                      0.0                  0.000000
# 5                      0.0                      0.0                  0.000000
#
#    share_customer_region_12  c_tct_yearly_perc_volume  \
# 0                       0.0                       1.0
# 1                       0.0                       1.0
# 2                       0.0                       1.0
# 3                       0.0                       1.0
# 4                       0.0                       1.0
# 5                       0.0                       1.0
#
#    c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 0                  83.243195        80.028811                  83.243195
# 1                  74.033377        74.158198                  74.158198
# 2                  81.753914        74.105795                  81.753914
# 3                  81.243410        81.564842                  81.564842
# 4                  81.056569        77.007044                  81.056569
# 5                  81.995280        82.551881                  82.551881
#
#     performance_label  source_customer_id
# 0       Top Performer         id_10002106
# 1       Top Performer         id_10002106
# 2       Top Performer         id_10002106
# 3       Top Performer         id_10002106
# 4       Top Performer         id_10002106
# 5  Non Regular Client         id_10002106
#
# [6 rows x 25 columns]
#    customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 0  id_10588990                  21037.98                      5.853351
# 1  id_12739765                  45413.30                      7.492767
# 2  id_12999049                  39822.42                      7.151045
# 3  id_13359459                  94769.73                      5.812761
# 4  id_14037504                   7157.68                      6.464347
# 5  id_10002106                  54587.16                      6.537076
#
#    share_customer_region_13  share_customer_region_7  share_customer_region_3  \
# 0                  0.000000                 0.080379                 0.000000
# 1                  0.000000                 0.000000                 0.000000
# 2                  0.000000                 0.000728                 0.000000
# 3                  0.000000                 0.000000                 0.000000
# 4                  0.000000                 0.010397                 0.000000
# 5                  0.082142                 0.000000                 0.105354
#
#    share_customer_region_6  share_customer_region_16  \
# 0                 0.000000                       0.0
# 1                 0.000000                       0.0
# 2                 0.001544                       0.0
# 3                 0.000000                       0.0
# 4                 0.000000                       0.0
# 5                 0.000000                       0.0
#
#    share_customer_region_10  share_customer_region_15  ...  \
# 0                  0.000000                       0.0  ...
# 1                  0.000000                       0.0  ...
# 2                  0.984124                       0.0  ...
# 3                  0.000000                       0.0  ...
# 4                  0.973099                       0.0  ...
# 5                  0.000000                       0.0  ...
#
#    share_customer_region_5  share_customer_region_1  share_customer_region_11  \
# 0                      0.0                      0.0                  0.919621
# 1                      0.0                      0.0                  0.000000
# 2                      0.0                      0.0                  0.000000
# 3                      0.0                      0.0                  0.000000
# 4                      0.0                      0.0                  0.000000
# 5                      0.0                      0.0                  0.000000
#
#    share_customer_region_12  c_tct_yearly_perc_volume  \
# 0                       0.0                       1.0
# 1                       0.0                       1.0
# 2                       0.0                       1.0
# 3                       0.0                       1.0
# 4                       0.0                       1.0
# 5                       0.0                       1.0
#
#    c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 0                  83.243195        80.028811                  83.243195
# 1                  74.033377        74.158198                  74.158198
# 2                  81.753914        74.105795                  81.753914
# 3                  81.243410        81.564842                  81.564842
# 4                  81.056569        77.007044                  81.056569
# 5                  81.995280        82.551881                  82.551881
#
#     performance_label  source_customer_id
# 0       Top Performer         id_10002106
# 1       Top Performer         id_10002106
# 2       Top Performer         id_10002106
# 3       Top Performer         id_10002106
# 4       Top Performer         id_10002106
# 5  Non Regular Client         id_10002106
#
# [6 rows x 25 columns]
#    customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 6   idg_004083                 428715.64                      6.536986
# 7  id_10003969                 467554.74                      6.056923
#
#    share_customer_region_13  share_customer_region_7  share_customer_region_3  \
# 6                  0.001254                 0.000000                 0.356107
# 7                  0.017476                 0.005429                 0.331679
#
#    share_customer_region_6  share_customer_region_16  \
# 6                 0.000000                  0.000000
# 7                 0.004913                  0.000364
#
#    share_customer_region_10  share_customer_region_15  ...  \
# 6                       0.0                  0.004785  ...
# 7                       0.0                  0.226920  ...
#
#    share_customer_region_5  share_customer_region_1  share_customer_region_11  \
# 6                 0.253697                  0.01113                       0.0
# 7                 0.012985                  0.05190                       0.0
#
#    share_customer_region_12  c_tct_yearly_perc_volume  \
# 6                       0.0                       1.0
# 7                       0.0                       1.0
#
#    c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 6                  73.338444        72.634074                  73.338444
# 7                  68.382604        72.384576                  72.384576
#
#    performance_label  source_customer_id
# 6      Top Performer         id_10003969
# 7    Under Performer         id_10003969
#
# [2 rows x 25 columns]
#       customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 39346  idg_002062                5525272.43                      8.304919
# 39347  idg_002286                5265948.54                     12.099910
# 39348  idg_004009                7160925.07                     14.738973
# 39349  idg_002268                6177347.71                      7.012209
#
#        share_customer_region_13  share_customer_region_7  \
# 39346                  0.006473                 0.882699
# 39347                  0.004531                 0.019290
# 39348                  0.099165                 0.000302
# 39349                  0.005737                 0.130192
#
#        share_customer_region_3  share_customer_region_6  \
# 39346                 0.001555                 0.048052
# 39347                 0.012106                 0.031523
# 39348                 0.156882                 0.000401
# 39349                 0.001094                 0.052831
#
#        share_customer_region_16  share_customer_region_10  \
# 39346                  0.096713                  0.000985
# 39347                  0.024093                  0.127702
# 39348                  0.013806                  0.157722
# 39349                  0.153572                  0.015124
#
#        share_customer_region_15  ...  share_customer_region_5  \
# 39346                  0.000000  ...                 0.003018
# 39347                  0.000957  ...                 0.011508
# 39348                  0.024095  ...                 0.319878
# 39349                  0.000000  ...                 0.000518
#
#        share_customer_region_1  share_customer_region_11  \
# 39346                 0.000466                       0.0
# 39347                 0.001179                       0.0
# 39348                 0.202943                       0.0
# 39349                 0.000047                       0.0
#
#        share_customer_region_12  c_tct_yearly_perc_volume  \
# 39346                       0.0                  0.934261
# 39347                       0.0                  0.931732
# 39348                       0.0                  0.773099
# 39349                       0.0                  0.947002
#
#        c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 39346                  12.838100        13.039137                  13.039137
# 39347                  18.305771        18.303127                  18.305771
# 39348                  16.747873        16.870696                  16.870696
# 39349                   4.828791        25.636272                  25.636272
#
#        performance_label  source_customer_id
# 39346      Top Performer          idg_002268
# 39347      Top Performer          idg_002268
# 39348      Top Performer          idg_002268
# 39349    Under Performer          idg_002268
#
# [4 rows x 25 columns]
#       customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 39346  idg_002062                5525272.43                      8.304919
# 39347  idg_002286                5265948.54                     12.099910
# 39348  idg_004009                7160925.07                     14.738973
# 39349  idg_002268                6177347.71                      7.012209
#
#        share_customer_region_13  share_customer_region_7  \
# 39346                  0.006473                 0.882699
# 39347                  0.004531                 0.019290
# 39348                  0.099165                 0.000302
# 39349                  0.005737                 0.130192
#
#        share_customer_region_3  share_customer_region_6  \
# 39346                 0.001555                 0.048052
# 39347                 0.012106                 0.031523
# 39348                 0.156882                 0.000401
# 39349                 0.001094                 0.052831
#
#        share_customer_region_16  share_customer_region_10  \
# 39346                  0.096713                  0.000985
# 39347                  0.024093                  0.127702
# 39348                  0.013806                  0.157722
# 39349                  0.153572                  0.015124
#
#        share_customer_region_15  ...  share_customer_region_5  \
# 39346                  0.000000  ...                 0.003018
# 39347                  0.000957  ...                 0.011508
# 39348                  0.024095  ...                 0.319878
# 39349                  0.000000  ...                 0.000518
#
#        share_customer_region_1  share_customer_region_11  \
# 39346                 0.000466                       0.0
# 39347                 0.001179                       0.0
# 39348                 0.202943                       0.0
# 39349                 0.000047                       0.0
#
#        share_customer_region_12  c_tct_yearly_perc_volume  \
# 39346                       0.0                  0.934261
# 39347                       0.0                  0.931732
# 39348                       0.0                  0.773099
# 39349                       0.0                  0.947002
#
#        c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 39346                  12.838100        13.039137                  13.039137
# 39347                  18.305771        18.303127                  18.305771
# 39348                  16.747873        16.870696                  16.870696
# 39349                   4.828791        25.636272                  25.636272
#
#        performance_label  source_customer_id
# 39346      Top Performer          idg_002268
# 39347      Top Performer          idg_002268
# 39348      Top Performer          idg_002268
# 39349    Under Performer          idg_002268
#
# [4 rows x 25 columns]
#       customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 39346  idg_002062                5525272.43                      8.304919
# 39347  idg_002286                5265948.54                     12.099910
# 39348  idg_004009                7160925.07                     14.738973
# 39349  idg_002268                6177347.71                      7.012209
#
#        share_customer_region_13  share_customer_region_7  \
# 39346                  0.006473                 0.882699
# 39347                  0.004531                 0.019290
# 39348                  0.099165                 0.000302
# 39349                  0.005737                 0.130192
#
#        share_customer_region_3  share_customer_region_6  \
# 39346                 0.001555                 0.048052
# 39347                 0.012106                 0.031523
# 39348                 0.156882                 0.000401
# 39349                 0.001094                 0.052831
#
#        share_customer_region_16  share_customer_region_10  \
# 39346                  0.096713                  0.000985
# 39347                  0.024093                  0.127702
# 39348                  0.013806                  0.157722
# 39349                  0.153572                  0.015124
#
#        share_customer_region_15  ...  share_customer_region_5  \
# 39346                  0.000000  ...                 0.003018
# 39347                  0.000957  ...                 0.011508
# 39348                  0.024095  ...                 0.319878
# 39349                  0.000000  ...                 0.000518
#
#        share_customer_region_1  share_customer_region_11  \
# 39346                 0.000466                       0.0
# 39347                 0.001179                       0.0
# 39348                 0.202943                       0.0
# 39349                 0.000047                       0.0
#
#        share_customer_region_12  c_tct_yearly_perc_volume  \
# 39346                       0.0                  0.934261
# 39347                       0.0                  0.931732
# 39348                       0.0                  0.773099
# 39349                       0.0                  0.947002
#
#        c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 39346                  12.838100        13.039137                  13.039137
# 39347                  18.305771        18.303127                  18.305771
# 39348                  16.747873        16.870696                  16.870696
# 39349                   4.828791        25.636272                  25.636272
#
#        performance_label  source_customer_id
# 39346      Top Performer          idg_002268
# 39347      Top Performer          idg_002268
# 39348      Top Performer          idg_002268
# 39349    Under Performer          idg_002268
#
# [4 rows x 25 columns]
#       customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 39346  idg_002062                5525272.43                      8.304919
# 39347  idg_002286                5265948.54                     12.099910
# 39348  idg_004009                7160925.07                     14.738973
# 39349  idg_002268                6177347.71                      7.012209
#
#        share_customer_region_13  share_customer_region_7  \
# 39346                  0.006473                 0.882699
# 39347                  0.004531                 0.019290
# 39348                  0.099165                 0.000302
# 39349                  0.005737                 0.130192
#
#        share_customer_region_3  share_customer_region_6  \
# 39346                 0.001555                 0.048052
# 39347                 0.012106                 0.031523
# 39348                 0.156882                 0.000401
# 39349                 0.001094                 0.052831
#
#        share_customer_region_16  share_customer_region_10  \
# 39346                  0.096713                  0.000985
# 39347                  0.024093                  0.127702
# 39348                  0.013806                  0.157722
# 39349                  0.153572                  0.015124
#
#        share_customer_region_15  ...  share_customer_region_5  \
# 39346                  0.000000  ...                 0.003018
# 39347                  0.000957  ...                 0.011508
# 39348                  0.024095  ...                 0.319878
# 39349                  0.000000  ...                 0.000518
#
#        share_customer_region_1  share_customer_region_11  \
# 39346                 0.000466                       0.0
# 39347                 0.001179                       0.0
# 39348                 0.202943                       0.0
# 39349                 0.000047                       0.0
#
#        share_customer_region_12  c_tct_yearly_perc_volume  \
# 39346                       0.0                  0.934261
# 39347                       0.0                  0.931732
# 39348                       0.0                  0.773099
# 39349                       0.0                  0.947002
#
#        c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 39346                  12.838100        13.039137                  13.039137
# 39347                  18.305771        18.303127                  18.305771
# 39348                  16.747873        16.870696                  16.870696
# 39349                   4.828791        25.636272                  25.636272
#
#        performance_label  source_customer_id
# 39346      Top Performer          idg_002268
# 39347      Top Performer          idg_002268
# 39348      Top Performer          idg_002268
# 39349    Under Performer          idg_002268
#
# [4 rows x 25 columns]
#       customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 39346  idg_002062                5525272.43                      8.304919
# 39347  idg_002286                5265948.54                     12.099910
# 39348  idg_004009                7160925.07                     14.738973
# 39349  idg_002268                6177347.71                      7.012209
#
#        share_customer_region_13  share_customer_region_7  \
# 39346                  0.006473                 0.882699
# 39347                  0.004531                 0.019290
# 39348                  0.099165                 0.000302
# 39349                  0.005737                 0.130192
#
#        share_customer_region_3  share_customer_region_6  \
# 39346                 0.001555                 0.048052
# 39347                 0.012106                 0.031523
# 39348                 0.156882                 0.000401
# 39349                 0.001094                 0.052831
#
#        share_customer_region_16  share_customer_region_10  \
# 39346                  0.096713                  0.000985
# 39347                  0.024093                  0.127702
# 39348                  0.013806                  0.157722
# 39349                  0.153572                  0.015124
#
#        share_customer_region_15  ...  share_customer_region_5  \
# 39346                  0.000000  ...                 0.003018
# 39347                  0.000957  ...                 0.011508
# 39348                  0.024095  ...                 0.319878
# 39349                  0.000000  ...                 0.000518
#
#        share_customer_region_1  share_customer_region_11  \
# 39346                 0.000466                       0.0
# 39347                 0.001179                       0.0
# 39348                 0.202943                       0.0
# 39349                 0.000047                       0.0
#
#        share_customer_region_12  c_tct_yearly_perc_volume  \
# 39346                       0.0                  0.934261
# 39347                       0.0                  0.931732
# 39348                       0.0                  0.773099
# 39349                       0.0                  0.947002
#
#        c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 39346                  12.838100        13.039137                  13.039137
# 39347                  18.305771        18.303127                  18.305771
# 39348                  16.747873        16.870696                  16.870696
# 39349                   4.828791        25.636272                  25.636272
#
#        performance_label  source_customer_id
# 39346      Top Performer          idg_002268
# 39347      Top Performer          idg_002268
# 39348      Top Performer          idg_002268
# 39349    Under Performer          idg_002268
#
# [4 rows x 25 columns]
#       customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 39346  idg_002062                5525272.43                      8.304919
# 39347  idg_002286                5265948.54                     12.099910
# 39348  idg_004009                7160925.07                     14.738973
# 39349  idg_002268                6177347.71                      7.012209
#
#        share_customer_region_13  share_customer_region_7  \
# 39346                  0.006473                 0.882699
# 39347                  0.004531                 0.019290
# 39348                  0.099165                 0.000302
# 39349                  0.005737                 0.130192
#
#        share_customer_region_3  share_customer_region_6  \
# 39346                 0.001555                 0.048052
# 39347                 0.012106                 0.031523
# 39348                 0.156882                 0.000401
# 39349                 0.001094                 0.052831
#
#        share_customer_region_16  share_customer_region_10  \
# 39346                  0.096713                  0.000985
# 39347                  0.024093                  0.127702
# 39348                  0.013806                  0.157722
# 39349                  0.153572                  0.015124
#
#        share_customer_region_15  ...  share_customer_region_5  \
# 39346                  0.000000  ...                 0.003018
# 39347                  0.000957  ...                 0.011508
# 39348                  0.024095  ...                 0.319878
# 39349                  0.000000  ...                 0.000518
#
#        share_customer_region_1  share_customer_region_11  \
# 39346                 0.000466                       0.0
# 39347                 0.001179                       0.0
# 39348                 0.202943                       0.0
# 39349                 0.000047                       0.0
#
#        share_customer_region_12  c_tct_yearly_perc_volume  \
# 39346                       0.0                  0.934261
# 39347                       0.0                  0.931732
# 39348                       0.0                  0.773099
# 39349                       0.0                  0.947002
#
#        c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 39346                  12.838100        13.039137                  13.039137
# 39347                  18.305771        18.303127                  18.305771
# 39348                  16.747873        16.870696                  16.870696
# 39349                   4.828791        25.636272                  25.636272
#
#        performance_label  source_customer_id
# 39346      Top Performer          idg_002268
# 39347      Top Performer          idg_002268
# 39348      Top Performer          idg_002268
# 39349    Under Performer          idg_002268
#
# [4 rows x 25 columns]
#       customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 39657  idg_004009                7160925.07                     14.738973
# 39658  idg_002062                5525272.43                      8.304919
# 39659  idg_002286                5265948.54                     12.099910
# 39660  idg_004208                6530865.41                      4.561095
#
#        share_customer_region_13  share_customer_region_7  \
# 39657                  0.099165                 0.000302
# 39658                  0.006473                 0.882699
# 39659                  0.004531                 0.019290
# 39660                  0.011015                 0.000000
#
#        share_customer_region_3  share_customer_region_6  \
# 39657                 0.156882                 0.000401
# 39658                 0.001555                 0.048052
# 39659                 0.012106                 0.031523
# 39660                 0.139586                 0.000066
#
#        share_customer_region_16  share_customer_region_10  \
# 39657                  0.013806                  0.157722
# 39658                  0.096713                  0.000985
# 39659                  0.024093                  0.127702
# 39660                  0.000038                  0.000000
#
#        share_customer_region_15  ...  share_customer_region_5  \
# 39657                  0.024095  ...                 0.319878
# 39658                  0.000000  ...                 0.003018
# 39659                  0.000957  ...                 0.011508
# 39660                  0.089737  ...                 0.001670
#
#        share_customer_region_1  share_customer_region_11  \
# 39657                 0.202943                       0.0
# 39658                 0.000466                       0.0
# 39659                 0.001179                       0.0
# 39660                 0.008303                       0.0
#
#        share_customer_region_12  c_tct_yearly_perc_volume  \
# 39657                       0.0                  0.773099
# 39658                       0.0                  0.934261
# 39659                       0.0                  0.931732
# 39660                       0.0                  1.000000
#
#        c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 39657                  16.747873        16.870696                  16.870696
# 39658                  12.838100        13.039137                  13.039137
# 39659                  18.305771        18.303127                  18.305771
# 39660                   5.550581        24.986163                  24.986163
#
#        performance_label  source_customer_id
# 39657      Top Performer          idg_004208
# 39658      Top Performer          idg_004208
# 39659      Top Performer          idg_004208
# 39660    Under Performer          idg_004208
#
# [4 rows x 25 columns]
#        customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 37161   idg_004009                7160925.07                     14.738973
# 37162   idg_006208                4776769.90                      1.275482
# 37163  id_91426000                7127174.53                      2.417351
#
#        share_customer_region_13  share_customer_region_7  \
# 37161                  0.099165                 0.000302
# 37162                  1.218865                 1.728563
# 37163                  0.005457                 0.000000
#
#        share_customer_region_3  share_customer_region_6  \
# 37161                 0.156882                 0.000401
# 37162                 1.912848                 0.496580
# 37163                 0.000027                 0.000000
#
#        share_customer_region_16  share_customer_region_10  \
# 37161                  0.013806                  0.157722
# 37162                  0.748670                  2.556602
# 37163                  0.000000                  0.000000
#
#        share_customer_region_15  ...  share_customer_region_5  \
# 37161                  0.024095  ...                 0.319878
# 37162                  0.000000  ...                 0.112161
# 37163                  0.000000  ...                 0.001626
#
#        share_customer_region_1  share_customer_region_11  \
# 37161                 0.202943                       0.0
# 37162                 0.769349                       0.0
# 37163                 0.000752                       0.0
#
#        share_customer_region_12  c_tct_yearly_perc_volume  \
# 37161                       0.0                  0.773099
# 37162                       0.0                  0.066196
# 37163                       0.0                  0.190383
#
#        c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 37161                  16.747873        16.870696                  16.870696
# 37162                  67.766355        67.861837                  67.861837
# 37163                  33.447768        33.928062                  33.928062
#
#        performance_label  source_customer_id
# 37161      Top Performer         id_91426000
# 37162      Top Performer         id_91426000
# 37163      Top Performer         id_91426000
#
# [3 rows x 25 columns]
# Empty DataFrame
# Columns: [customer_id, c_yearly_network_volumen, c_weighted_competitive_index, share_customer_region_13, share_customer_region_7, share_customer_region_3, share_customer_region_6, share_customer_region_16, share_customer_region_10, share_customer_region_15, share_customer_region_14, share_customer_region_8, share_customer_region_4, share_customer_region_9, share_customer_region_2, share_customer_region_5, share_customer_region_1, share_customer_region_11, share_customer_region_12, c_tct_yearly_perc_volume, c_yearly_margin_per_liter, predicted_value, corrected_predicted_value, performance_label, source_customer_id]
# Index: []
#
# [0 rows x 25 columns]
#    customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 6   idg_004083                 428715.64                      6.536986
# 7  id_10003969                 467554.74                      6.056923
#
#    share_customer_region_13  share_customer_region_7  share_customer_region_3  \
# 6                  0.001254                 0.000000                 0.356107
# 7                  0.017476                 0.005429                 0.331679
#
#    share_customer_region_6  share_customer_region_16  \
# 6                 0.000000                  0.000000
# 7                 0.004913                  0.000364
#
#    share_customer_region_10  share_customer_region_15  ...  \
# 6                       0.0                  0.004785  ...
# 7                       0.0                  0.226920  ...
#
#    share_customer_region_5  share_customer_region_1  share_customer_region_11  \
# 6                 0.253697                  0.01113                       0.0
# 7                 0.012985                  0.05190                       0.0
#
#    share_customer_region_12  c_tct_yearly_perc_volume  \
# 6                       0.0                       1.0
# 7                       0.0                       1.0
#
#    c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 6                  73.338444        72.634074                  73.338444
# 7                  68.382604        72.384576                  72.384576
#
#    performance_label  source_customer_id
# 6      Top Performer         id_10003969
# 7    Under Performer         id_10003969
#
# [2 rows x 25 columns]
#    customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 0  id_10588990                  21037.98                      5.853351
# 1  id_12739765                  45413.30                      7.492767
# 2  id_12999049                  39822.42                      7.151045
# 3  id_13359459                  94769.73                      5.812761
# 4  id_14037504                   7157.68                      6.464347
# 5  id_10002106                  54587.16                      6.537076
#
#    share_customer_region_13  share_customer_region_7  share_customer_region_3  \
# 0                  0.000000                 0.080379                 0.000000
# 1                  0.000000                 0.000000                 0.000000
# 2                  0.000000                 0.000728                 0.000000
# 3                  0.000000                 0.000000                 0.000000
# 4                  0.000000                 0.010397                 0.000000
# 5                  0.082142                 0.000000                 0.105354
#
#    share_customer_region_6  share_customer_region_16  \
# 0                 0.000000                       0.0
# 1                 0.000000                       0.0
# 2                 0.001544                       0.0
# 3                 0.000000                       0.0
# 4                 0.000000                       0.0
# 5                 0.000000                       0.0
#
#    share_customer_region_10  share_customer_region_15  ...  \
# 0                  0.000000                       0.0  ...
# 1                  0.000000                       0.0  ...
# 2                  0.984124                       0.0  ...
# 3                  0.000000                       0.0  ...
# 4                  0.973099                       0.0  ...
# 5                  0.000000                       0.0  ...
#
#    share_customer_region_5  share_customer_region_1  share_customer_region_11  \
# 0                      0.0                      0.0                  0.919621
# 1                      0.0                      0.0                  0.000000
# 2                      0.0                      0.0                  0.000000
# 3                      0.0                      0.0                  0.000000
# 4                      0.0                      0.0                  0.000000
# 5                      0.0                      0.0                  0.000000
#
#    share_customer_region_12  c_tct_yearly_perc_volume  \
# 0                       0.0                       1.0
# 1                       0.0                       1.0
# 2                       0.0                       1.0
# 3                       0.0                       1.0
# 4                       0.0                       1.0
# 5                       0.0                       1.0
#
#    c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 0                  83.243195        80.028811                  83.243195
# 1                  74.033377        74.158198                  74.158198
# 2                  81.753914        74.105795                  81.753914
# 3                  81.243410        81.564842                  81.564842
# 4                  81.056569        77.007044                  81.056569
# 5                  81.995280        82.551881                  82.551881
#
#     performance_label  source_customer_id
# 0       Top Performer         id_10002106
# 1       Top Performer         id_10002106
# 2       Top Performer         id_10002106
# 3       Top Performer         id_10002106
# 4       Top Performer         id_10002106
# 5  Non Regular Client         id_10002106
#
# [6 rows x 25 columns]
#     customer_id  c_yearly_network_volumen  c_weighted_competitive_index  \
# 58  id_76159430                  62009.64                     13.626100
# 59  id_76820749                  21773.17                     14.076810
# 60  id_76898830                  36537.41                     14.357876
# 61  id_77187422                  45163.25                     13.965111
# 62  id_79765510                  32533.79                     13.705522
# 63  id_10060685                  26804.80                     13.732275
#
#     share_customer_region_13  share_customer_region_7  \
# 58                  0.355716                 0.115451
# 59                  1.000000                 0.000000
# 60                  0.565847                 0.000000
# 61                  0.124262                 0.157544
# 62                  0.149888                 0.024883
# 63                  0.875201                 0.077391
#
#     share_customer_region_3  share_customer_region_6  \
# 58                 0.000000                 0.115260
# 59                 0.000000                 0.000000
# 60                 0.016562                 0.000825
# 61                 0.000000                 0.020985
# 62                 0.000000                 0.048676
# 63                 0.000000                 0.023391
#
#     share_customer_region_16  share_customer_region_10  \
# 58                  0.059669                  0.084546
# 59                  0.000000                  0.000000
# 60                  0.000000                  0.000000
# 61                  0.150826                  0.006375
# 62                  0.072399                  0.001726
# 63                  0.000000                  0.000000
#
#     share_customer_region_15  ...  share_customer_region_5  \
# 58                  0.000000  ...                 0.000000
# 59                  0.000000  ...                 0.000000
# 60                  0.000000  ...                 0.014700
# 61                  0.000000  ...                 0.000000
# 62                  0.012068  ...                 0.061286
# 63                  0.000000  ...                 0.024017
#
#     share_customer_region_1  share_customer_region_11  \
# 58                 0.000000                       0.0
# 59                 0.000000                       0.0
# 60                 0.000000                       0.0
# 61                 0.000000                       0.0
# 62                 0.024176                       0.0
# 63                 0.000000                       0.0
#
#     share_customer_region_12  c_tct_yearly_perc_volume  \
# 58                  0.000000                       1.0
# 59                  0.000000                       1.0
# 60                  0.000000                       1.0
# 61                  0.000000                       1.0
# 62                  0.061871                       1.0
# 63                  0.000000                       1.0
#
#     c_yearly_margin_per_liter  predicted_value  corrected_predicted_value  \
# 58                  78.122696        77.606871                  78.122696
# 59                  81.275399        78.570880                  81.275399
# 60                  79.681917        79.995913                  79.995913
# 61                  77.052199        73.621793                  77.052199
# 62                  79.304047        78.540097                  79.304047
# 63                  75.833035        79.190425                  79.190425
#
#     performance_label  source_customer_id
# 58      Top Performer         id_10060685
# 59      Top Performer         id_10060685
# 60      Top Performer         id_10060685
# 61      Top Performer         id_10060685
# 62      Top Performer         id_10060685
# 63    Under Performer         id_10060685
#
# [6 rows x 25 columns]
